# %%
import pandas as pd
import numpy as np

# %%
micro1 = pd.read_csv('../raw/data/DataRecords.csv', index_col='FID')
micro1.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27872\4125224204.py in <module>
# ----> 1 micro1 = pd.read_csv('../raw/data/DataRecords.csv', index_col='FID')
#       2 micro1.columns
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
micro1.isnull().sum()

# %%
micro1.dtypes

# %%
micro1.DOI.unique()

# %%
micro1['NCEI Accession Link'].unique()

# %%
micro1['Short Reference'].unique()

# %%
micro1['Keywords'].unique()

# %%
micro1['Organization'].unique()

# %%
micro1 = micro1.drop(columns = ['DOI', 'NCEI Accession Number', 'NCEI Accession Link', 'Short Reference', 'Long Reference', 'Keywords', 'Organization', 'x', 'y'])

# %%
micro1.to_csv('../cleaned/micro1.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1572\2173099473.py in <module>
# ----> 1 micro1.to_csv('../cleaned/micro1.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
df2 = pd.read_excel('./1260352_supportingfile_suppl._excel_seq1_v1.xlsx')
# Out:
# C:\Users\jeffr\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
df2.head()
# Out:
#              Country Economic status1  Coastal population2  \
# 0            Albania              LMI            2530533.0
# 1           Algeria8              UMI           16556580.0
# 2             Angola              LMI            3790041.0
# 3           Anguilla              HIC              14561.0
# 4  Antigua & Barbuda              HIC              66843.0
#
#    Waste generation rate [kg/person/day]3  % Plastic in waste stream4  \
# 0                                    0.77                        8.95
# 1                                    1.20                       11.95
# 2                                    0.48                       12.95
# 3                                    2.10                       11.95
# 4                                    5.50                       11.95
#
#    % Inadequately managed waste5  % Littered waste6  \
# 0                      44.667603                2.0
# 1                      58.069448                2.0
# ...

# %%
df5 = pd.read_csv('./Marine_Microplastics.csv')

# %%
df5.head()
# Out:
#        X      Y  FID                    Date  Latitude  Longitude  \
# 0 -70.65  40.93    1  1989/10/12 00:00:00+00     40.93     -70.65
# 1 -70.65  40.93    2  1989/10/12 00:00:00+00     40.93     -70.65
# 2 -69.77  40.30    3  1989/10/12 00:00:00+00     40.30     -69.77
# 3 -67.15  39.88    4  1989/10/15 00:00:00+00     39.88     -67.15
# 4 -63.73  37.83    5  1989/10/18 00:00:00+00     37.83     -63.73
#
#            Oceans Regions SubRegions  Measuremen  ...  DensText   SampMethod  \
# 0  Atlantic Ocean                       0.002276  ...       Low  Neuston net
# 1  Atlantic Ocean                       0.004320  ...       Low  Neuston net
# 2  Atlantic Ocean                       0.000000  ...  Very Low  Neuston net
# 3  Atlantic Ocean                       0.000000  ...  Very Low  Neuston net
# 4  Atlantic Ocean                       0.043196  ...    Medium  Neuston net
#
#          ShortRef                                            LongRef  \
# ...

# %%
df5.shape
# Out:
# (14340, 22)

# %%
df5.tail()
# Out:
#                X          Y    FID                    Date   Latitude  \
# 14335   4.671167  43.314833  28677  2021/10/05 00:00:00+00  43.314833
# 14336   4.400167  43.327167  28678  2021/10/05 00:00:00+00  43.327167
# 14337 -13.442667  29.237000  28679  2020/10/31 00:00:00+00  29.237000
# 14338 -13.830000  28.734000  28680  2020/11/12 00:00:00+00  28.734000
# 14339 -16.627333  28.005833  28681  2020/11/28 00:00:00+00  28.005833
#
#        Longitude          Oceans            Regions     SubRegions  \
# 14335   4.671167  Atlantic Ocean  Mediterranean Sea  Western Basin
# 14336   4.400167  Atlantic Ocean  Mediterranean Sea  Western Basin
# 14337 -13.442667  Atlantic Ocean
# 14338 -13.830000  Atlantic Ocean
# 14339 -16.627333  Atlantic Ocean
#
#        Measuremen  ... DensText SampMethod          ShortRef  \
# 14335    0.157077  ...   Medium  Manta net  Faure et al.2015
# 14336    0.143505  ...   Medium  Manta net  Faure et al.2015
# ...

# %%
for i in df5.columns:
    print(i)
# Out:
# X
# Y
# FID
# Date
# Latitude
# Longitude
# Oceans
# Regions
# SubRegions
# Measuremen
# Unit
# DensRange
# DensText
# SampMethod
# ShortRef
# LongRef
# DOI
# Org
# Keywords
# AccessNo
# AccessLink
# GlobalID

# %%
min(df5.Date)
# Out:
# '1972/04/20 00:00:00+00'

# %%
max(df5.Date)
# Out:
# '2021/10/05 00:00:00+00'

# %%
df5.Unit.unique()
# Out:
# array(['pieces/m3'], dtype=object)

# %%
df5.SampMethod.unique()
# Out:
# array(['Neuston net', 'Grab sample', 'Intake seawater', 'Manta net',
#        'AVANI net', 'Plankton net', 'Surface water intake',
#        'Aluminum bucket', 'Stainless steel bucket'], dtype=object)
